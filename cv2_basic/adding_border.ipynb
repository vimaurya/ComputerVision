# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load an image
image = cv2.imread('../data/kobe.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

top, bottom, left, right = 10, 10, 10, 10

border_color = [255, 0, 0]

bordered_image_constant = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_CONSTANT, value=border_color)
bordered_image_reflect = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_REFLECT)
bordered_image_replicate = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_REPLICATE)
bordered_image_wrap = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_WRAP)
bordered_image_reflect101 = cv2.copyMakeBorder(image, top, bottom, left, right, cv2.BORDER_REFLECT_101)

plt.figure(figsize=(15, 10))

plt.subplot(231)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')

plt.subplot(232)
plt.imshow(bordered_image_constant)
plt.title('BORDER_CONSTANT')
plt.axis('off')

plt.subplot(233)
plt.imshow(bordered_image_reflect)
plt.title('BORDER_REFLECT')
plt.axis('off')

plt.subplot(234)
plt.imshow(bordered_image_replicate)
plt.title('BORDER_REPLICATE')
plt.axis('off')

plt.subplot(235)
plt.imshow(bordered_image_wrap)
plt.title('BORDER_WRAP')
plt.axis('off')

plt.subplot(236)
plt.imshow(bordered_image_reflect101)
plt.title('BORDER_REFLECT_101')
plt.axis('off')

plt.show()
